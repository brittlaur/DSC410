# %%
#Brittany Roberts
#DSC410
#Exercise 8.2

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/bellevue-university/dsc410/main/12%20Week/week_8/data/travel_insurance.csv')
df
# Out:
#       Agency    Agency Type Distribution Channel  \
# 0        CBH  Travel Agency              Offline
# 1        CBH  Travel Agency              Offline
# 2        CWT  Travel Agency               Online
# 3        CWT  Travel Agency               Online
# 4        CWT  Travel Agency               Online
# ...      ...            ...                  ...
# 63321    JZI       Airlines               Online
# 63322    JZI       Airlines               Online
# 63323    JZI       Airlines               Online
# 63324    JZI       Airlines               Online
# 63325    JZI       Airlines               Online
#
#                           Product Name Claim  Duration Destination  Net Sales  \
# 0                   Comprehensive Plan    No       186    MALAYSIA      -29.0
# 1                   Comprehensive Plan    No       186    MALAYSIA      -29.0
# 2      Rental Vehicle Excess Insurance    No        65   AUSTRALIA      -49.5
# ...

# %%
df.describe()
# Out:
#            Duration     Net Sales  Commision (in value)           Age
# count  63326.000000  63326.000000          63326.000000  63326.000000
# mean      49.317074     40.702018              9.809992     39.969981
# std      101.791566     48.845637             19.804388     14.017010
# min       -2.000000   -389.000000              0.000000      0.000000
# 25%        9.000000     18.000000              0.000000     35.000000
# 50%       22.000000     26.530000              0.000000     36.000000
# 75%       53.000000     48.000000             11.550000     43.000000
# max     4881.000000    810.000000            283.500000    118.000000

# %%
numerical_features = ['Duration', 'Net Sales', 'Commision (in value)', 'Age']
categorical_features = ['Agency', 'Agency Type', 'Distribution Channel', 'Product Name', 'Claim', 'Destination', 'Gender']

# %% [markdown]
# EDA for Numerical Features

# %%
def desc_num_feature(feature_name, bins=30, edgecolor='k', **kwargs):
    fig, ax = plt.subplots(figsize=(8,4))
    df[feature_name].hist(bins=bins, edgecolor=edgecolor, ax=ax, **kwargs)
    ax.set_title(feature_name, size=15)
    plt.figtext(1,0.15, str(df[feature_name].describe().round(2).astype(str)), size=17)

# %%
for x in numerical_features:
    desc_num_feature(x)

# %%
#Correlation for numerical features

df[numerical_features].corr()
# Out:
#                       Duration  Net Sales  Commision (in value)       Age
# Duration              1.000000   0.429235              0.344772  0.002468
# Net Sales             0.429235   1.000000              0.651315  0.037756
# Commision (in value)  0.344772   0.651315              1.000000  0.118348
# Age                   0.002468   0.037756              0.118348  1.000000

# %%
sns.pairplot(df[numerical_features], plot_kws={'s':2}, diag_kind='kde');

# %% [markdown]
# EDA for Categorical Features

# %%
feature = categorical_features[0]
count = df[feature].value_counts()
percent = 100*df[feature].value_counts(normalize=True)
df1 = pd.DataFrame({'count' :count, 'percent' :percent.round(1)})
print(df1)
count.plot(kind='bar', title=feature, subplots=True);
# Out:
#      count  percent
# EPX  35119     55.5
# CWT   8580     13.5
# C2B   8267     13.1
# JZI   6329     10.0
# SSI   1056      1.7
# JWT    749      1.2
# RAB    725      1.1
# LWC    689      1.1
# TST    528      0.8
# KML    392      0.6
# ART    331      0.5
# CCR    194      0.3
# CBH    101      0.2
# TTW     98      0.2
# CSR     86      0.1
# ADM     82      0.1

# %%
feature = categorical_features[1]
count = df[feature].value_counts()
percent = 100*df[feature].value_counts(normalize=True)
df1 = pd.DataFrame({'count' :count, 'percent' :percent.round(1)})
print(df1)
count.plot(kind='bar', title=feature, subplots=True);
# Out:
#                count  percent
# Travel Agency  45869     72.4
# Airlines       17457     27.6

# %%
feature = categorical_features[2]
count = df[feature].value_counts()
percent = 100*df[feature].value_counts(normalize=True)
df1 = pd.DataFrame({'count' :count, 'percent' :percent.round(1)})
print(df1)
count.plot(kind='bar', title=feature, subplots=True);
# Out:
#          count  percent
# Online   62219     98.3
# Offline   1107      1.7

# %%
feature = categorical_features[3]
count = df[feature].value_counts()
percent = 100*df[feature].value_counts(normalize=True)
df1 = pd.DataFrame({'count' :count, 'percent' :percent.round(1)})
print(df1)
count.plot(kind='bar', title=feature, subplots=True);
# Out:
#                                       count  percent
# Cancellation Plan                     18630     29.4
# 2 way Comprehensive Plan              13158     20.8
# Rental Vehicle Excess Insurance        8580     13.5
# Basic Plan                             5469      8.6
# Bronze Plan                            4049      6.4
# 1 way Comprehensive Plan               3331      5.3
# Value Plan                             2715      4.3
# Silver Plan                            2249      3.6
# Annual Silver Plan                     1423      2.2
# Ticket Protector                       1056      1.7
# Travel Cruise Protect                   527      0.8
# Comprehensive Plan                      364      0.6
# Gold Plan                               352      0.6
# 24 Protect                              247      0.4
# Single Trip Travel Protect Gold         204      0.3
# Annual Gold Plan                        194      0.3
# Premier Plan                            194      0.3
# ...

# %%
feature = categorical_features[4]
count = df[feature].value_counts()
percent = 100*df[feature].value_counts(normalize=True)
df1 = pd.DataFrame({'count' :count, 'percent' :percent.round(1)})
print(df1)
count.plot(kind='bar', title=feature, subplots=True);
# Out:
#      count  percent
# No   62399     98.5
# Yes    927      1.5

# %%
feature = categorical_features[5]
count = df[feature].value_counts()
percent = 100*df[feature].value_counts(normalize=True)
df1 = pd.DataFrame({'count' :count, 'percent' :percent.round(1)})
print(df1)
count.plot(kind='bar', title=feature, subplots=True);
# Out:
#                         count  percent
# SINGAPORE               13255     20.9
# MALAYSIA                 5930      9.4
# THAILAND                 5894      9.3
# CHINA                    4796      7.6
# AUSTRALIA                3694      5.8
# ...                       ...      ...
# SEYCHELLES                  1      0.0
# SAMOA                       1      0.0
# NIGERIA                     1      0.0
# DOMINICAN REPUBLIC          1      0.0
# BOSNIA AND HERZEGOVINA      1      0.0
#
# [149 rows x 2 columns]

# %%
feature = categorical_features[6]
count = df[feature].value_counts()
percent = 100*df[feature].value_counts(normalize=True)
df1 = pd.DataFrame({'count' :count, 'percent' :percent.round(1)})
print(df1)
count.plot(kind='bar', title=feature, subplots=True);
# Out:
#    count  percent
# M   9347     51.3
# F   8872     48.7

# %% [markdown]
# Crosstabs to see the counts of a claim being filed for each data

# %%
#Categorical Data

pd.crosstab(df['Agency'], df['Claim'])
# Out:
# Claim      No  Yes
# Agency
# ADM        82    0
# ART       330    1
# C2B      7720  547
# CBH       100    1
# CCR       191    3
# CSR        85    1
# CWT      8494   86
# EPX     34924  195
# JWT       745    4
# JZI      6298   31
# KML       384    8
# LWC       653   36
# RAB       724    1
# SSI      1049    7
# TST       526    2
# TTW        94    4

# %%
pd.crosstab(df['Agency Type'], df['Claim'])
# Out:
# Claim             No  Yes
# Agency Type
# Airlines       16866  591
# Travel Agency  45533  336

# %%
pd.crosstab(df['Distribution Channel'], df['Claim'])
# Out:
# Claim                    No  Yes
# Distribution Channel
# Offline                1090   17
# Online                61309  910

# %%
pd.crosstab(df['Product Name'], df['Claim'])
# Out:
# Claim                                    No  Yes
# Product Name
# 1 way Comprehensive Plan               3322    9
# 2 way Comprehensive Plan              13016  142
# 24 Protect                              247    0
# Annual Gold Plan                        173   21
# Annual Silver Plan                     1266  157
# Annual Travel Protect Gold               90   10
# Annual Travel Protect Platinum           50    3
# Annual Travel Protect Silver             82    4
# Basic Plan                             5446   23
# Bronze Plan                            3839  210
# Cancellation Plan                     18586   44
# Child Comprehensive Plan                  9    0
# Comprehensive Plan                      359    5
# Gold Plan                               334   18
# Individual Comprehensive Plan            71    3
# Premier Plan                            191    3
# Rental Vehicle Excess Insurance        8494   86
# Silver Plan                            2108  141
# ...

# %%
pd.crosstab(df['Destination'], df['Claim'])
# Out:
# Claim                   No  Yes
# Destination
# ALBANIA                  1    0
# ANGOLA                   1    0
# ARGENTINA               21    1
# ARMENIA                  1    0
# AUSTRALIA             3656   38
# ...                    ...  ...
# VENEZUELA                5    0
# VIET NAM              1657   12
# VIRGIN ISLANDS, U.S.     1    0
# ZAMBIA                   3    0
# ZIMBABWE                 3    0
#
# [149 rows x 2 columns]

# %%
pd.crosstab(df['Gender'], df['Claim'])
# Out:
# Claim     No  Yes
# Gender
# F       8526  346
# M       9054  293

# %%
#Numerical Data

pd.crosstab(df['Duration'], df['Claim'])
# Out:
# Claim       No  Yes
# Duration
# -2           1    0
# -1           4    0
#  0          61    0
#  1         816    1
#  2        1497    6
# ...        ...  ...
#  4831        1    0
#  4844        1    0
#  4847        1    0
#  4857        1    0
#  4881        1    0
#
# [455 rows x 2 columns]

# %%
pd.crosstab(df['Net Sales'], df['Claim'])
# Out:
# Claim      No  Yes
# Net Sales
# -389.00     1    0
# -357.50     1    0
# -297.00     1    0
# -291.75     3    0
# -289.00     1    0
# ...        ..  ...
#  586.00     1    0
#  599.00     5    0
#  666.00     2    0
#  682.00     1    0
#  810.00     1    0
#
# [1139 rows x 2 columns]

# %%
pd.crosstab(df['Commision (in value)'], df['Claim'])
# Out:
# Claim                    No  Yes
# Commision (in value)
# 0.00                  35018  199
# 0.02                     14    0
# 0.04                      1    0
# 0.05                     14    0
# 0.09                     13    0
# ...                     ...  ...
# 209.95                    3    0
# 210.21                   36    3
# 262.60                    2    0
# 262.76                    6    0
# 283.50                    1    0
#
# [1035 rows x 2 columns]

# %%
pd.crosstab(df['Age'], df['Claim'])
# Out:
# Claim   No  Yes
# Age
# 0        2    0
# 1        5    0
# 2        1    0
# 3        4    0
# 4        1    0
# ..     ...  ...
# 85       9    0
# 86       4    0
# 87       8    0
# 88       4    0
# 118    974   10
#
# [89 rows x 2 columns]

# %% [markdown]
# Count of NaN values for all columns to determine which will be useful

# %%
print('NaN Count for Agency:', df['Agency'].isnull().sum())
print('NaN Count for Agency Type:', df['Agency Type'].isnull().sum())
print('NaN Count for Distribution Channel:', df['Distribution Channel'].isnull().sum())
print('NaN Count for Product Name:', df['Product Name'].isnull().sum())
print('NaN Count for Clain:', df['Claim'].isnull().sum())
print('NaN Count for Duration:', df['Duration'].isnull().sum())
print('NaN Count for Net Sales:', df['Net Sales'].isnull().sum())
print('NaN Count for Commision (in value):', df['Commision (in value)'].isnull().sum())
print('NaN Count for Gender:', df['Gender'].isnull().sum())
print('NaN Count for Age:', df['Age'].isnull().sum())
# Out:
# NaN Count for Agency: 0
# NaN Count for Agency Type: 0
# NaN Count for Distribution Channel: 0
# NaN Count for Product Name: 0
# NaN Count for Clain: 0
# NaN Count for Duration: 0
# NaN Count for Net Sales: 0
# NaN Count for Commision (in value): 0
# NaN Count for Gender: 45107
# NaN Count for Age: 0

# %% [markdown]
# Dropping Gender column due to NaN values being the majority of the data.
# Dropping Destination as it has a high number of unique values, which I don't think will help contribute to the model due to variability.

# %%
df.drop(df.columns[[6,9]], axis=1, inplace=True)
df
# Out:
#       Agency    Agency Type Distribution Channel  \
# 0        CBH  Travel Agency              Offline
# 1        CBH  Travel Agency              Offline
# 2        CWT  Travel Agency               Online
# 3        CWT  Travel Agency               Online
# 4        CWT  Travel Agency               Online
# ...      ...            ...                  ...
# 63321    JZI       Airlines               Online
# 63322    JZI       Airlines               Online
# 63323    JZI       Airlines               Online
# 63324    JZI       Airlines               Online
# 63325    JZI       Airlines               Online
#
#                           Product Name Claim  Duration  Net Sales  \
# 0                   Comprehensive Plan    No       186      -29.0
# 1                   Comprehensive Plan    No       186      -29.0
# 2      Rental Vehicle Excess Insurance    No        65      -49.5
# 3      Rental Vehicle Excess Insurance    No        60      -39.6
# ...

# %% [markdown]
# Label encoding all categorical data to make it easier to use in model

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
df['encoded_Agency'] = le.fit_transform(df['Agency'])
df
# Out:
#       Agency    Agency Type Distribution Channel  \
# 0        CBH  Travel Agency              Offline
# 1        CBH  Travel Agency              Offline
# 2        CWT  Travel Agency               Online
# 3        CWT  Travel Agency               Online
# 4        CWT  Travel Agency               Online
# ...      ...            ...                  ...
# 63321    JZI       Airlines               Online
# 63322    JZI       Airlines               Online
# 63323    JZI       Airlines               Online
# 63324    JZI       Airlines               Online
# 63325    JZI       Airlines               Online
#
#                           Product Name Claim  Duration  Net Sales  \
# 0                   Comprehensive Plan    No       186      -29.0
# 1                   Comprehensive Plan    No       186      -29.0
# 2      Rental Vehicle Excess Insurance    No        65      -49.5
# 3      Rental Vehicle Excess Insurance    No        60      -39.6
# ...

# %%
df['encoded_Agency_Type'] = le.fit_transform(df['Agency Type'])
df['encoded_Distribution'] = le.fit_transform(df['Distribution Channel'])
df['encoded_Product'] = le.fit_transform(df['Product Name'])
df['encoded_Claim'] = le.fit_transform(df['Claim'])
df
# Out:
#       Agency    Agency Type Distribution Channel  \
# 0        CBH  Travel Agency              Offline
# 1        CBH  Travel Agency              Offline
# 2        CWT  Travel Agency               Online
# 3        CWT  Travel Agency               Online
# 4        CWT  Travel Agency               Online
# ...      ...            ...                  ...
# 63321    JZI       Airlines               Online
# 63322    JZI       Airlines               Online
# 63323    JZI       Airlines               Online
# 63324    JZI       Airlines               Online
# 63325    JZI       Airlines               Online
#
#                           Product Name Claim  Duration  Net Sales  \
# 0                   Comprehensive Plan    No       186      -29.0
# 1                   Comprehensive Plan    No       186      -29.0
# 2      Rental Vehicle Excess Insurance    No        65      -49.5
# 3      Rental Vehicle Excess Insurance    No        60      -39.6
# ...

# %%
encoded_features = ['encoded_Agency', 'encoded_Agency_Type', 'encoded_Distribution', 'encoded_Product']
numerical_features = ['Duration', 'Net Sales', 'Age', 'Commision (in value)']

X = df[numerical_features + encoded_features]
y = df['encoded_Claim'].astype(int)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 101)

# %%
#standardize numerical features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train[numerical_features + encoded_features])
X_train.loc[:, numerical_features + encoded_features] = scaler.transform(X_train[numerical_features + encoded_features])

# %% [markdown]
# Decision tree was used because a logistic model and KNN didn't work in my mind due to columns given wouldn't affect why a person would make a claim. So it would make it too difficult for the model to use the training data.

# %%
from sklearn.tree import DecisionTreeClassifier
class_tree = DecisionTreeClassifier(max_depth=3)
class_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
import six
from six import StringIO
from sklearn.tree import export_graphviz
from IPython.display import Image
import pydotplus

# %%
dot_data = StringIO()
export_graphviz(decision_tree=class_tree,
                out_file=dot_data,
                filled=True,
                rounded=True,
                feature_names=X_train.columns,
                class_names = ['0','1'],
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
class_tree = DecisionTreeClassifier(max_depth=6, min_samples_split=50)
class_tree.fit(X_train, y_train)
y_pred_class_tree = class_tree.predict(X_train)

# %%
from sklearn.metrics import accuracy_score

accuracy_class_tree = accuracy_score(y_true=y_train,
                                     y_pred=y_pred_class_tree)
accuracy_class_tree
# Out:
# 0.9853841699857877

# %%
pd.Series(data=class_tree.feature_importances_,
          index=X_train.columns).sort_values(ascending=False).round(3)
# Out:
# encoded_Agency          0.480
# Net Sales               0.264
# Duration                0.203
# Age                     0.029
# Commision (in value)    0.018
# encoded_Product         0.008
# encoded_Agency_Type     0.000
# encoded_Distribution    0.000
# dtype: float64

# %% [markdown]
# Created random forest classifier to further test the accuracy of the training data.

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=99,
                            max_features=5,
                            max_depth=4,
                            min_samples_split=100,
                            random_state=85)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_train)

# %%
accuracy_rf = accuracy_score(y_true=y_train, y_pred=y_pred_rf)
accuracy_rf
# Out:
# 0.9853139859280964

# %%
pd.Series(data=rf.feature_importances_,
          index=X_train.columns).sort_values(ascending=False).round(3)
# Out:
# encoded_Agency          0.462
# Net Sales               0.279
# Duration                0.106
# Commision (in value)    0.084
# Age                     0.036
# encoded_Product         0.017
# encoded_Agency_Type     0.015
# encoded_Distribution    0.001
# dtype: float64

# %%
#Test the model

y_pred_null = np.zeros_like(y_test)
accuracy_score(y_true=y_test, y_pred = y_pred_null)
# Out:
# 0.9857887257224064

# %% [markdown]
# Validation of Model

# %%
#Confusion matrix
from sklearn.metrics import confusion_matrix

def CM(y_true, y_pred):
    M = confusion_matrix(y_true, y_pred)
    out = pd.DataFrame(M, index=['Obs No', 'Obs Yes'],
                                columns=['Pred No', 'Pred Yes'])
    return out

# %%
threshold = 0.5
y_pred_prob = rf.predict_proba(X_test)[:,1]
y_pred = (y_pred_prob > threshold).astype(int)

# %%
CM(y_test, y_pred)
# Out:
#          Pred No  Pred Yes
# Obs No      6243         0
# Obs Yes       90         0

# %%
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision:  {:0.1f}%, Recall: {:.1f}%'.format(100*precision, 100*recall))
# Out:
# Precision:  0.0%, Recall: 0.0%
# C:\Users\Brittany\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# It makes sense that the precision and recall are low because ultimately the categories used to predict if the person would make a claim would not make a difference.  The correlation between claims and any category is low, which would make it harder to make predictions based on that.  It also does not help that the amount of people that did make claims is only 1.5% of the data, giving the model no reason to not predict a no.

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.kdeplot(y_pred_prob[y_test==0], shade=True, color='red',
label='No', ax=ax)
sns.kdeplot(y_pred_prob[y_test==1], shade=True, color='green',
label='Yes', ax=ax)
ax.set_title('Distribution of predicted probabilities', fontsize=16)
ax.legend()
plt.grid();
